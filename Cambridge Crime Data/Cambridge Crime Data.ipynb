# %% [markdown]
# # CAMBRIDGE CRIME DATA ANALYSIS

# %% [markdown]
# ## DATA COLLECTION

# %% [markdown]
# The dataset is taken from open source dataset kaggle https://www.kaggle.com/datasets/melissamonfared/cambridge-crime-data-2009-2024

# %%
import pandas as pd
import numpy as np
# Out:
# /Users/ammu/Desktop/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("Crime_Reports_20240701.csv")

# %%
df
# Out:
#       File Number          Date of Report  \
# 0      2009-01323  02/21/2009 09:53:00 AM
# 1      2009-01324  02/21/2009 09:59:00 AM
# 2      2009-01327  02/21/2009 12:32:00 PM
# 3      2009-01331  02/21/2009 03:05:00 PM
# 4      2009-01346  02/22/2009 05:02:00 AM
# ...           ...                     ...
# 95918  2024-03755  05/07/2024 01:13:00 PM
# 95919  2024-03756  05/07/2024 02:41:00 PM
# 95920  2024-03777  05/07/2024 08:13:00 PM
# 95921  2024-03806  05/08/2024 04:09:00 PM
# 95922  2024-03824  05/09/2024 10:23:00 AM
#
#                            Crime Date Time               Crime  \
# 0                 02/21/2009 09:20 - 09:30             Threats
# 1      02/20/2009 22:30 - 02/21/2009 10:00          Auto Theft
# 2      02/19/2009 21:00 - 02/21/2009 12:00         Hit and Run
# 3                 02/21/2009 15:00 - 15:10      Larceny (Misc)
# 4                         02/22/2009 05:02                 OUI
# ...                                    ...                 ...
# ...

# %%
df.head()
# Out:
#   File Number          Date of Report                      Crime Date Time  \
# 0  2009-01323  02/21/2009 09:53:00 AM             02/21/2009 09:20 - 09:30
# 1  2009-01324  02/21/2009 09:59:00 AM  02/20/2009 22:30 - 02/21/2009 10:00
# 2  2009-01327  02/21/2009 12:32:00 PM  02/19/2009 21:00 - 02/21/2009 12:00
# 3  2009-01331  02/21/2009 03:05:00 PM             02/21/2009 15:00 - 15:10
# 4  2009-01346  02/22/2009 05:02:00 AM                     02/22/2009 05:02
#
#             Crime  Reporting Area     Neighborhood  \
# 0         Threats           105.0   East Cambridge
# 1      Auto Theft          1109.0  North Cambridge
# 2     Hit and Run          1109.0  North Cambridge
# 3  Larceny (Misc)          1303.0  Strawberry Hill
# 4             OUI           105.0   East Cambridge
#
#                             Location
# 0         100 OTIS ST, Cambridge, MA
# 1      400 RINDGE AVE, Cambridge, MA
# 2      400 RINDGE AVE, Cambridge, MA
# 3      0 NORUMBEGA ST, Cambridge, MA
# ...

# %% [markdown]
# ## DATA DESCRIPTION

# %%
df.size
# Out:
# 671461

# %%
df.columns
# Out:
# Index(['File Number', 'Date of Report', 'Crime Date Time', 'Crime',
#        'Reporting Area', 'Neighborhood', 'Location'],
#       dtype='object')

# %%
df.head(5)
# Out:
#   File Number      Date of Report                      Crime Date Time  \
# 0  2009-01323 2009-02-21 09:53:00             02/21/2009 09:20 - 09:30
# 1  2009-01324 2009-02-21 09:59:00  02/20/2009 22:30 - 02/21/2009 10:00
# 2  2009-01327 2009-02-21 12:32:00  02/19/2009 21:00 - 02/21/2009 12:00
# 3  2009-01331 2009-02-21 15:05:00             02/21/2009 15:00 - 15:10
# 4  2009-01346 2009-02-22 05:02:00                     02/22/2009 05:02
#
#             Crime  Reporting Area     Neighborhood  \
# 0         Threats           105.0   East Cambridge
# 1      Auto Theft          1109.0  North Cambridge
# 2     Hit and Run          1109.0  North Cambridge
# 3  Larceny (Misc)          1303.0  Strawberry Hill
# 4             OUI           105.0   East Cambridge
#
#                             Location    Crime Start Time      Crime End Time  \
# 0         100 OTIS ST, Cambridge, MA 2009-02-21 09:20:00 1900-01-01 09:30:00
# ...

# %% [markdown]
# ## DATA CLEANING

# %%
df['Date of Report'] = pd.to_datetime(df['Date of Report'])
df['date'] = df['Date of Report'].dt.day
df['month'] = df['Date of Report'].dt.month
df['year'] = df['Date of Report'].dt.year
df['time'] = df['Date of Report'].dt.time

# %%
df.head(5)
# Out:
#   File Number      Date of Report                      Crime Date Time  \
# 0  2009-01323 2009-02-21 09:53:00             02/21/2009 09:20 - 09:30
# 1  2009-01324 2009-02-21 09:59:00  02/20/2009 22:30 - 02/21/2009 10:00
# 2  2009-01327 2009-02-21 12:32:00  02/19/2009 21:00 - 02/21/2009 12:00
# 3  2009-01331 2009-02-21 15:05:00             02/21/2009 15:00 - 15:10
# 4  2009-01346 2009-02-22 05:02:00                     02/22/2009 05:02
#
#             Crime  Reporting Area     Neighborhood  \
# 0         Threats           105.0   East Cambridge
# 1      Auto Theft          1109.0  North Cambridge
# 2     Hit and Run          1109.0  North Cambridge
# 3  Larceny (Misc)          1303.0  Strawberry Hill
# 4             OUI           105.0   East Cambridge
#
#                             Location    Crime Start Time      Crime End Time  \
# 0         100 OTIS ST, Cambridge, MA 2009-02-21 09:20:00 1900-01-01 09:30:00
# ...

# %%
df=df.drop(columns="Date of Report")

# %%
df.head()
# Out:
#   File Number                      Crime Date Time           Crime  \
# 0  2009-01323             02/21/2009 09:20 - 09:30         Threats
# 1  2009-01324  02/20/2009 22:30 - 02/21/2009 10:00      Auto Theft
# 2  2009-01327  02/19/2009 21:00 - 02/21/2009 12:00     Hit and Run
# 3  2009-01331             02/21/2009 15:00 - 15:10  Larceny (Misc)
# 4  2009-01346                     02/22/2009 05:02             OUI
#
#    Reporting Area     Neighborhood                           Location  \
# 0           105.0   East Cambridge         100 OTIS ST, Cambridge, MA
# 1          1109.0  North Cambridge      400 RINDGE AVE, Cambridge, MA
# 2          1109.0  North Cambridge      400 RINDGE AVE, Cambridge, MA
# 3          1303.0  Strawberry Hill      0 NORUMBEGA ST, Cambridge, MA
# 4           105.0   East Cambridge  FIFTH ST & GORE ST, Cambridge, MA
#
#      Crime Start Time      Crime End Time     Time Difference  date  month  \
# ...

# %%
df.isna()
# Out:
#        File Number  Crime Date Time  Crime  Reporting Area  Neighborhood  \
# 0            False            False  False           False         False
# 1            False            False  False           False         False
# 2            False            False  False           False         False
# 3            False            False  False           False         False
# 4            False            False  False           False         False
# ...            ...              ...    ...             ...           ...
# 95918        False            False  False           False         False
# 95919        False            False  False           False         False
# 95920        False            False  False           False         False
# 95921        False            False  False           False         False
# 95922        False            False  False           False         False
#
#        Location  Crime Start Time  Crime End Time  Time Difference   date  \
# ...

# %%
df.isna().sum()
# Out:
# File Number             0
# Crime Date Time        11
# Crime                   0
# Reporting Area          8
# Neighborhood            8
# Location              295
# Crime Start Time       26
# Crime End Time      62777
# Time Difference     62777
# date                    0
# month                   0
# year                    0
# time                    0
# dtype: int64

# %%
df= df.fillna("Not Available")

# %%
df.isna().sum()
# Out:
# File Number         0
# Crime Date Time     0
# Crime               0
# Reporting Area      0
# Neighborhood        0
# Location            0
# Crime Start Time    0
# Crime End Time      0
# Time Difference     0
# date                0
# month               0
# year                0
# time                0
# dtype: int64

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
import matplotlib.pyplot as plt

# %%
years = df['year'].value_counts().sort_index()
plt.bar(years.index, years.values)
plt.title('Crime over the years')
plt.xlabel('Year')
plt.ylabel('Number of Crimes')
plt.show()

# %%
years = df['Neighborhood'].value_counts().sort_index()
plt.figure(figsize=(10, 8))  
plt.pie(years.values, labels=years.index, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Crimes in Neighborhood')
plt.axis('equal') 
plt.show()

# %%
# Finding top 10 crimes
top_10_crimes = df['Crime'].value_counts().head(10)

# %%
plt.figure(figsize=(10, 6))
top_10_crimes.plot(kind='bar', color='violet')
plt.xlabel('Crime Type')
plt.ylabel('Count')
plt.title('Top 10 Crimes')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
#Finding top 10 locations that are high in crimes
top_10_locations = df['Location'].value_counts().head(10)

# %%
plt.figure(figsize=(10, 6))
bars = plt.barh(np.arange(len(top_10_locations)), top_10_locations.values, color='red')
plt.yticks(np.arange(len(top_10_locations)), top_10_locations.index)
plt.xlabel('Count')
plt.ylabel('Unsafe Locations')
plt.title('Top 10 Unsafe Locations')

# Adding counts on the bars
for i, count in enumerate(top_10_locations.values):
    plt.text(count + 0.1, i, str(count), va='center', ha='left')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# Overall this project aims at analysing the crime of Cambridge that has been implemented successfully.This report helps to understand the danger areas,most frequent types of crimes that are happening the most,the distribution of crimes over areas ,overall year analysis of crime all these provides valuable information with which one could avoid those places, be aware and can expect more decrease in crime in upcoming years.
